# %%
import sys, os
sys.path.append(os.path.abspath("/Users/DavidHolzwarth/Uni/EPFL/bachelors-thesis"))

import numpy as np
from LP import resolve_delegations_LP, invert_graph
from graph_viz import visualize_delegation_graph

np.random.seed(1)

WEIGHTS = [(i + 1) / 10 for i in range(1, 10)]
NUM_NODES = 10
NUM_LOOPS = 5

def get_random_delegation_weights(n: int) -> list:
    """
    Generates at most `n` random weights from the set of {0.1, 0.2, ..., 0.9} such that they sum to exactly 1.0.

    Parameters:
    - n (int): The number of weights to generate.

    Returns:
    - list[float]: A list of `n` values that sum to 1.0.

    Notes:
        - If `n == 0`, an empty list is returned.
        - The algorithm may find less than 'n' weights, if e.g. n = 2, but the first weight is 1.0, then it will only return [1.0]
        - The last weight is explicitly adjusted to correct any rounding errors.
        - The algorithm ensures no negative values by rejecting choices that exceed the remaining sum.
    """
    if n == 0: return []

    diff = 1
    weights = []
    for i in range(n-1):
        for j in range(11):
            # Tries 10 times to find a valid weight. If this is not possible the algorithm gives up
            choice = np.random.choice(WEIGHTS)
            if diff - choice > 0:
                weights += [choice]
                diff -= weights[-1]
                break
    
    # If we have not used all the weights, add the last one
    if diff > 0:
        weights += [round(diff, 1)]

    return weights

def is_connected_to_sink(delegations, start_node):

    visited = set()

    def dfs(node):
        if node in visited:
            return False 
        
        visited.add(node)

        # A sink is a node with no outgoing edges 
        if node not in delegations or not delegations[node]:  
            return True  

        # Recur for all outgoing connections
        return any(dfs(neighbor) for neighbor in delegations[node])

    return dfs(start_node)

nodes = []
delegations = {}
for i in range(NUM_NODES):
    node = str(i)
    nodes += [node]
    # Choose how many delegations this node shall have
    num_delegations = np.random.randint(0, min(3, i) + 1)
    if num_delegations > 0:
        delegation_weights = get_random_delegation_weights(num_delegations)

        delegates = np.random.choice(nodes, num_delegations, replace=False)
        # Sorting assures that if the node delegates to itself, this delegation is first in the list.
        delegates = sorted(delegates, reverse=True) 

        for j in range(len(delegation_weights)):
            delegate = delegates[j]

            # Avoids delegations of N -1-> N, which are not allowed (since N is not voting and voting at the same time)
            if (delegate == node) and ((delegation_weights[j] == 1) or delegations.get(node, {}).get(node, 0) + delegation_weights[j] == 1):
                # If the only delegate is itself, turn this node into a sink by just not adding the delegation 
                if len(delegates) == 1:
                    break 
                # Else remove the delegation, and add the weight to the next delegate's weight
                else:
                    delegation_weights[j + 1] +=  delegation_weights[j] 
                    continue

            else:
                delegations.setdefault(node, {}).setdefault(delegate, 0)
                delegations[node][delegate] += delegation_weights[j]

for i in range(NUM_LOOPS):
    
    # Try to find a non-sink node with which to create a loop
    node = None
    for j in range(len(nodes)):
        node = np.random.choice(nodes)
        if node not in delegations or len(delegations[node]) == 0:
            node = None
        else:
            break

    for j, delegate in enumerate(delegations.get(node, {})):
        # Try to create a loop between this node and the selected delegate

        # Delegate is a sink
        if not delegations.get(delegate):
            # Add the loop
            delegations[delegate] = {node: 1}

            # Check that we did not create an illegal cycle
            if not is_connected_to_sink(delegations, node):
                # Remove the loop
                del delegations[delegate]
                continue
        # Delegate is not a sink
        else:
            delegates_delegates = delegations[delegate]

            # Choose any weight from the set of weights, except 1
            # Adding a new delegation with weight 1 might create a cycle
            new_delegation_weight = np.random.choice([weight for weight in WEIGHTS if weight not in [1]])

            # Free up weight from the other delegations
            for k, v in delegations[delegate].items():
                    delegations[delegate][k] = (1 - new_delegation_weight) * v

            # Add this weight directed toward the node, to create a loop 
            delegations[delegate].setdefault(node, 0)
            delegations[delegate][node] += new_delegation_weight

            break


# %timeit resolve_delegations_LP(invert_graph(delegations), nodes)
powers, sink_nodes = resolve_delegations_LP(invert_graph(delegations), nodes)
display(powers)
for node in nodes:
    if node not in sink_nodes:
        powers[node] = 0
display(powers)
visualize_delegation_graph(delegations, powers)
# Out:
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/f607823fdbd344ffb5ee83945a76bab9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/f607823fdbd344ffb5ee83945a76bab9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/766bebeeec964da4a2f6d8fd9ce61cf1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/766bebeeec964da4a2f6d8fd9ce61cf1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/7f583a137aa24bdcbb7042661476110c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/7f583a137aa24bdcbb7042661476110c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/08f403b2930b45289f15020e7fbe5957-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/08f403b2930b45289f15020e7fbe5957-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/f42308fa40fd4e6f9a1e70a78d062b89-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/f42308fa40fd4e6f9a1e70a78d062b89-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/6afd54bb62ae4d6bb0908706b48170f6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/6afd54bb62ae4d6bb0908706b48170f6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/344165c9b55546b189d60322bdc61b67-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/344165c9b55546b189d60322bdc61b67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/a2181a0898fb4584986bff65f8c530bc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/a2181a0898fb4584986bff65f8c530bc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/0287f0df49e94675a2f6c63faf2fbd96-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/0287f0df49e94675a2f6c63faf2fbd96-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/381cb8a061ea4f0e88353563bf7460c7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/381cb8a061ea4f0e88353563bf7460c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/64f13300fcbc4cfe9b5a6ab609152575-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/64f13300fcbc4cfe9b5a6ab609152575-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/c90498147a4442c5a2ded07540b06ded-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/c90498147a4442c5a2ded07540b06ded-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/8ca4222205b947658c0d10c0d8919b2a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/8ca4222205b947658c0d10c0d8919b2a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/e4e53793c7254e758a0592afead18c25-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/e4e53793c7254e758a0592afead18c25-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/26d2e425310e45458b83c1c1f6e66b51-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/26d2e425310e45458b83c1c1f6e66b51-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/83fe1d9bb3004117a97af0c4c413e7dc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/83fe1d9bb3004117a97af0c4c413e7dc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/841f50c8a50c4cab9809b041be3f4ac3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/841f50c8a50c4cab9809b041be3f4ac3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/ab9d59580b0d4ec48072fca5ee3a667e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/ab9d59580b0d4ec48072fca5ee3a667e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/0ecd97ff304140b28fc27d66f41a9fec-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/0ecd97ff304140b28fc27d66f41a9fec-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/da83e042af8e46fb9d9190da7e9add35-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/da83e042af8e46fb9d9190da7e9add35-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/d8cae6abd3284aa2a2a31a35d55a9ba4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/d8cae6abd3284aa2a2a31a35d55a9ba4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/ce1ebcf9873d4be4af09269a516be8a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/ce1ebcf9873d4be4af09269a516be8a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/cd68257aa3ac4599a1838e854de0aeee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/cd68257aa3ac4599a1838e854de0aeee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/2b71a07f6d304b7cb27e9ad1ae23d080-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/2b71a07f6d304b7cb27e9ad1ae23d080-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/af99de5566bc49bbaa027fd100eb2246-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/af99de5566bc49bbaa027fd100eb2246-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/1e93c5966b8248b1b9820b193b1c3328-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/1e93c5966b8248b1b9820b193b1c3328-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/9d335b2a13f0490887e4b27a9fd8f2c1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/9d335b2a13f0490887e4b27a9fd8f2c1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/b71299066bfa452592238adc5205aed2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/b71299066bfa452592238adc5205aed2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/c9873082ea00466689e250c92f1f1b75-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/c9873082ea00466689e250c92f1f1b75-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/90512bed990c4a64af2a4959c46ac2c7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/90512bed990c4a64af2a4959c46ac2c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ...
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/5ed8f393a1e14df7a02c12d4d64ba2e1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/5ed8f393a1e14df7a02c12d4d64ba2e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/2de3fd1442a643e996eed1baf2e99b09-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/2de3fd1442a643e996eed1baf2e99b09-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/35ef34c0052046df920b74bc317e6573-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/35ef34c0052046df920b74bc317e6573-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/02fcfa3bd58a43cb8ab47ce0d29f1c13-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/02fcfa3bd58a43cb8ab47ce0d29f1c13-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/df09cf2670bf428595d8abfc1e435253-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/df09cf2670bf428595d8abfc1e435253-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/17e4a875a0e84c5f9cea407d10f33cb3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/17e4a875a0e84c5f9cea407d10f33cb3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/c23bc758538c4fa6b162759d9b8484bb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/c23bc758538c4fa6b162759d9b8484bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/2d5bacd0e1b74e7c92f1d25a22929925-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/2d5bacd0e1b74e7c92f1d25a22929925-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/46553e0e4af4481da84968e9351add1f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/46553e0e4af4481da84968e9351add1f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 18.4 ms ± 198 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# OrderedDict({'Constraint_0': 1*0 + -1*1 + -1 = 0, 'Constraint_1': 1*1 + -1*6 + -1 = 0, 'Constraint_2': 1*2 + -0.05600000000000001*4 + -0.1*8 + -1.0 = 0, 'Constraint_3': 1*3 + -0.11200000000000002*4 + -0.6*7 + -0.9*8 + -1.0 = 0, 'Constraint_4': 0.16800000000000015*4 + -1.0 = 0, 'Constraint_5': 1*5 + -1 = 0, 'Constraint_6': 1*6 + -1 = 0, 'Constraint_7': 1*7 + -1.0*9 + -1.0 = 0, 'Constraint_8': 1*8 + -1 = 0, 'Constraint_9': -0.4*7 + 1*9 + -1.0 = 0, 'SinkNodesConstraint': 1*0 + 1*2 + 1*3 + 1*5 + -10 = 0})
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/envs/thesis/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/fbc3b25aa72f40b9bebd11c9ec43e2ed-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/q9/0xq_2r1503z58vb1xx__4r5m0000gn/T/fbc3b25aa72f40b9bebd11c9ec43e2ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 41 RHS
# At line 53 BOUNDS
# At line 65 ENDATA
# Problem MODEL has 11 rows, 11 columns and 23 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-11) rows, 0 (-11) columns and 0 (-23) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# {'0': 3.0,
#  '1': 2.0,
#  '2': 1.4333333,
#  '3': 4.5666667,
#  '4': 5.952381,
#  '5': 1.0,
#  '6': 1.0,
#  '7': 3.3333333,
#  '8': 1.0,
#  '9': 2.3333333}
# {'0': 3.0,
#  '1': 0,
#  '2': 1.4333333,
#  '3': 4.5666667,
#  '4': 0,
#  '5': 1.0,
#  '6': 0,
#  '7': 0,
#  '8': 0,
#  '9': 0}
# Parsing the data...Done
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No trigger
# Modifying node size using  power
# No trigger
